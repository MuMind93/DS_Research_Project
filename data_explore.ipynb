# %%
import pandas as pd

# Define the years and file paths
years = range(2020, 2025)  # From 2020 to 2024
file_template = "DEVICE{}.txt"  # File pattern

# List to store DataFrames
df_list = []

# Read each file, add a 'year' column, and append to list
for year in years:
    file_path = file_template.format(year)
    try:
        df = pd.read_csv(file_path, delimiter="|", dtype=str, encoding="latin1", on_bad_lines="skip")
        df["year"] = year  # Add year column
        df_list.append(df)
        print(f"✅ {file_path} loaded successfully!")
    except Exception as e:
        print(f"❌ Error reading {file_path}:", e)

# Merge all DataFrames into one
if df_list:
    df_device_all = pd.concat(df_list, ignore_index=True)
    print("✅ All device data merged successfully!")
else:
    df_device_all = None
    print("❌ No files were loaded.")

# Display first few rows
df_device_all.head()
# Out:
# ✅ DEVICE2020.txt loaded successfully!
# ✅ DEVICE2021.txt loaded successfully!
# ✅ DEVICE2022.txt loaded successfully!
# ✅ DEVICE2023.txt loaded successfully!
# ✅ DEVICE2024.txt loaded successfully!
# ✅ All device data merged successfully!
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 30
#      27     print("❌ No files were loaded.")
#      29 # Display first few rows
# ---> 30 df_device_all.where().head()
#
# TypeError: NDFrame.where() missing 1 required positional argument: 'cond'

# %%
# Define the list of values to filter
dental_implant_names = [
    "DENTAL IMPLANT", 
    "ENDOSSEOUS DENTAL IMPLANT", 
    "IMPLANT, ENDOSSEOUS, ROOT-FORM"
]

# Filter the DataFrame for rows where GENERIC_NAME matches any of the list values
df_dental_implant = df_device_all[df_device_all["GENERIC_NAME"].isin(dental_implant_names)]

# Display the filtered DataFrame
print(df_dental_implant.head(5))
# Out:
#     MDR_REPORT_KEY DEVICE_EVENT_KEY IMPLANT_FLAG DATE_REMOVED_FLAG  \
# 2          9537111              NaN          NaN               NaN
# 197        9537306              NaN          NaN               NaN
# 198        9537307              NaN          NaN               NaN
# 199        9537308              NaN          NaN               NaN
# 200        9537309              NaN          NaN               NaN
#
#     DEVICE_SEQUENCE_NO DATE_RECEIVED  \
# 2                    1    2020/01/01
# 197                  1    2020/01/02
# 198                  1    2020/01/02
# 199                  1    2020/01/02
# 200                  1    2020/01/02
#
#                                    BRAND_NAME    GENERIC_NAME  \
# 2                     SIMPLY LEGACY 2 IMPLANT  DENTAL IMPLANT
# 197  ELEMENT IMPL., PF Ø 4.5, E Ø 4.2, L 14.0  DENTAL IMPLANT
# 198   ELEMENT RC INICELL, PF 3.5, E 3.5, L9.5  DENTAL IMPLANT
# 199   CONTACT RC INICELL, PF 4.0, E 3.5, L9.5  DENTAL IMPLANT
# 200     ELEMENT IMPL. RC INICELL® 3.0, L 12.5  DENTAL IMPLANT
#
#                          MANUFACTURER_D_NAME   MANUFACTURER_D_ADDRESS_1  ...  \
# 2    IMPLANT DIRECT SYBRON MANUFACTURING LLC  3050 EAST HILLCREST DRIVE  ...
# 197                       THOMMEN MEDICAL AG       NECKARSULMSTRASSE 28  ...
# 198                       THOMMEN MEDICAL AG       NECKARSULMSTRASSE 28  ...
# 199                       THOMMEN MEDICAL AG       NECKARSULMSTRASSE 28  ...
# 200                       THOMMEN MEDICAL AG       NECKARSULMSTRASSE 28  ...
#
#     OTHER_ID_NUMBER DEVICE_AVAILABILITY DATE_RETURNED_TO_MANUFACTURER  \
# 2               NaN                   Y                           NaN
# 197             NaN                   Y                           NaN
# 198             NaN                   Y                           NaN
# 199             NaN                   Y                           NaN
# 200             NaN                   Y                           NaN
#
#     DEVICE_REPORT_PRODUCT_CODE DEVICE_AGE_TEXT DEVICE_EVALUATED_BY_MANUFACTUR  \
# 2                          DZE             NaN                              N
# 197                        DZE             NaN                              N
# 198                        DZE             NaN                              N
# 199                        DZE             NaN                              N
# 200                        DZE             NaN                              N
#
#     COMBINATION_PRODUCT_FLAG          UDI-DI      UDI-PUBLIC  year
# 2                          N  10841307107415  10841307107415  2020
# 197                        N  07640156471441   7640156471441  2020
# 198                        N  07640156471304   7640156471304  2020
# 199                        N             NaN             NaN  2020
# 200                        N  07640156478556   7640156478556  2020
#
# [5 rows x 32 columns]

# %%
import pandas as pd

# Define the years and file paths
years = range(2020, 2025)  # From 2020 to 2024
file_template = "foitext{}.txt"  # File pattern

# List to store DataFrames
df_list = []

# Read each file, add a 'year' column, and append to list
for year in years:
    file_path = file_template.format(year)
    try:
        df = pd.read_csv(file_path, delimiter="|", dtype=str, encoding="latin1")
        df["year"] = year  # Add year column
        df_list.append(df)
        print(f"✅ {file_path} loaded successfully!")
    except Exception as e:
        print(f"❌ Error reading {file_path}:", e)

# Merge all DataFrames into one
if df_list:
    df_foitext_all = pd.concat(df_list, ignore_index=True)
    print("✅ All years merged successfully!")
else:
    df_foitext_all = None
    print("❌ No files were loaded.")

# Display first few rows
df_foitext_all.head()
# Out:
# ✅ foitext2020.txt loaded successfully!
# ✅ foitext2021.txt loaded successfully!
# ✅ foitext2022.txt loaded successfully!
# ✅ foitext2023.txt loaded successfully!
# ✅ foitext2024.txt loaded successfully!
# ✅ All years merged successfully!
#   MDR_REPORT_KEY MDR_TEXT_KEY TEXT_TYPE_CODE PATIENT_SEQUENCE_NUMBER  \
# 0        9537171    173269159              N                       1
# 1        9537171    173269160              D                       1
# 2        9537125    173269515              N                       1
# 3        9537125    173269516              D                       1
# 4        9537119    173269518              N                       1
#
#   DATE_REPORT                                           FOI_TEXT  year
# 0         NaN  THE RESULTS OF THE INVESTIGATION ARE INCONCLUS...  2020
# 1         NaN  IT WAS REPORTED THAT THE PATIENT EXPIRED. THER...  2020
# 2         NaN  INVESTIGATION RESULTS WILL BE PROVIDED IN THE ...  2020
# 3         NaN  IT WAS REPORTED THAT THE PATIENT CALLED EMERGE...  2020
# 4         NaN  THE RESULTS OF THE INVESTIGATION ARE INCONCLUS...  2020

# %%
df_foitext_all.dtypes
# Out:
# MDR_REPORT_KEY             object
# MDR_TEXT_KEY               object
# TEXT_TYPE_CODE             object
# PATIENT_SEQUENCE_NUMBER    object
# DATE_REPORT                object
# FOI_TEXT                   object
# year                        int64
# dtype: object

# %%
df_foitext_all.values_count()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/_6/bkb79v1n1qgb5pjgnzbz79nw0000gn/T/ipykernel_62670/2842008514.py in ?()
# ----> 1 df_foitext_all.values_count()
#
# ~/anaconda3/envs/deep_Learning/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'values_count'

# %%
# ---- Proceed only if both data frames loaded ----
if df_dental_implant is not None and df_foitext_all is not None:
    print("\n=== df_device Overview ===")
    print(df_dental_implant.info())

    print("\n=== df_foitext Overview ===")
    print(df_foitext_all.info())

    # ---- Merge on MDR_REPORT_KEY ----
    # 'how' can be 'inner', 'left', 'right', or 'outer', depending on what you need.
    df_merged = pd.merge(df_dental_implant, df_foitext_all, on="MDR_REPORT_KEY", how="inner")

    print("\n✅ Merged DataFrame (df_merged) Info ===")
    print(df_merged.info())

    # Now df_merged contains columns from both dfs for matching MDR_REPORT_KEY rows.
    print("\n=== First Few Rows of Merged Data ===")
    print(df_merged.head())

    # Example usage: Check for missing values in merged data
    print("\n=== Missing Values in Merged Data ===")
    print(df_merged.isnull().sum())

    # Export df_merged to CSV if needed
    # df_merged.to_csv("data/merged_output.csv", index=False)

else:
    print("\n❌ Could not merge because one of the DataFrames failed to load.")
# Out:
# === df_device Overview ===
# <class 'pandas.core.frame.DataFrame'>
# Index: 2344711 entries, 2 to 11507665
# Data columns (total 32 columns):
#  #   Column                          Dtype
# ---  ------                          -----
#  0   MDR_REPORT_KEY                  object
#  1   DEVICE_EVENT_KEY                object
#  2   IMPLANT_FLAG                    object
#  3   DATE_REMOVED_FLAG               object
#  4   DEVICE_SEQUENCE_NO              object
#  5   DATE_RECEIVED                   object
#  6   BRAND_NAME                      object
#  7   GENERIC_NAME                    object
#  8   MANUFACTURER_D_NAME             object
#  9   MANUFACTURER_D_ADDRESS_1        object
#  10  MANUFACTURER_D_ADDRESS_2        object
#  11  MANUFACTURER_D_CITY             object
#  12  MANUFACTURER_D_STATE_CODE       object
#  13  MANUFACTURER_D_ZIP_CODE         object
#  14  MANUFACTURER_D_ZIP_CODE_EXT     object
#  15  MANUFACTURER_D_COUNTRY_CODE     object
#  16  MANUFACTURER_D_POSTAL_CODE      object
#  17  DEVICE_OPERATOR                 object
#  18  EXPIRATION_DATE_OF_DEVICE       object
#  19  MODEL_NUMBER                    object
#  20  CATALOG_NUMBER                  object
#  21  LOT_NUMBER                      object
#  22  OTHER_ID_NUMBER                 object
#  23  DEVICE_AVAILABILITY             object
#  24  DATE_RETURNED_TO_MANUFACTURER   object
#  25  DEVICE_REPORT_PRODUCT_CODE      object
#  26  DEVICE_AGE_TEXT                 object
#  27  DEVICE_EVALUATED_BY_MANUFACTUR  object
#  28  COMBINATION_PRODUCT_FLAG        object
#  29  UDI-DI                          object
#  30  UDI-PUBLIC                      object
#  31  year                            int64
# dtypes: int64(1), object(31)
# memory usage: 590.3+ MB
# None
#
# === df_foitext Overview ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26837768 entries, 0 to 26837767
# Data columns (total 7 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   MDR_REPORT_KEY           object
#  1   MDR_TEXT_KEY             object
#  2   TEXT_TYPE_CODE           object
#  3   PATIENT_SEQUENCE_NUMBER  object
#  4   DATE_REPORT              object
#  5   FOI_TEXT                 object
#  6   year                     int64
# dtypes: int64(1), object(6)
# memory usage: 1.4+ GB
# None
#
# ✅ Merged DataFrame (df_merged) Info ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3634621 entries, 0 to 3634620
# Data columns (total 38 columns):
#  #   Column                          Dtype
# ---  ------                          -----
#  0   MDR_REPORT_KEY                  object
#  1   DEVICE_EVENT_KEY                object
#  2   IMPLANT_FLAG                    object
#  3   DATE_REMOVED_FLAG               object
#  4   DEVICE_SEQUENCE_NO              object
#  5   DATE_RECEIVED                   object
#  6   BRAND_NAME                      object
#  7   GENERIC_NAME                    object
#  8   MANUFACTURER_D_NAME             object
#  9   MANUFACTURER_D_ADDRESS_1        object
#  10  MANUFACTURER_D_ADDRESS_2        object
#  11  MANUFACTURER_D_CITY             object
#  12  MANUFACTURER_D_STATE_CODE       object
#  13  MANUFACTURER_D_ZIP_CODE         object
#  14  MANUFACTURER_D_ZIP_CODE_EXT     object
#  15  MANUFACTURER_D_COUNTRY_CODE     object
#  16  MANUFACTURER_D_POSTAL_CODE      object
#  17  DEVICE_OPERATOR                 object
#  18  EXPIRATION_DATE_OF_DEVICE       object
#  19  MODEL_NUMBER                    object
#  20  CATALOG_NUMBER                  object
#  21  LOT_NUMBER                      object
#  22  OTHER_ID_NUMBER                 object
#  23  DEVICE_AVAILABILITY             object
#  24  DATE_RETURNED_TO_MANUFACTURER   object
#  25  DEVICE_REPORT_PRODUCT_CODE      object
#  26  DEVICE_AGE_TEXT                 object
#  27  DEVICE_EVALUATED_BY_MANUFACTUR  object
#  28  COMBINATION_PRODUCT_FLAG        object
#  29  UDI-DI                          object
#  30  UDI-PUBLIC                      object
#  31  year_x                          int64
#  32  MDR_TEXT_KEY                    object
#  33  TEXT_TYPE_CODE                  object
#  34  PATIENT_SEQUENCE_NUMBER         object
#  35  DATE_REPORT                     object
#  36  FOI_TEXT                        object
#  37  year_y                          int64
# dtypes: int64(2), object(36)
# memory usage: 1.0+ GB
# None
#
# === First Few Rows of Merged Data ===
#   MDR_REPORT_KEY DEVICE_EVENT_KEY IMPLANT_FLAG DATE_REMOVED_FLAG  \
# 0        9537111              NaN          NaN               NaN
# 1        9537306              NaN          NaN               NaN
# 2        9537307              NaN          NaN               NaN
# 3        9537308              NaN          NaN               NaN
# 4        9537309              NaN          NaN               NaN
#
#   DEVICE_SEQUENCE_NO DATE_RECEIVED                                BRAND_NAME  \
# 0                  1    2020/01/01                   SIMPLY LEGACY 2 IMPLANT
# 1                  1    2020/01/02  ELEMENT IMPL., PF Ø 4.5, E Ø 4.2, L 14.0
# 2                  1    2020/01/02   ELEMENT RC INICELL, PF 3.5, E 3.5, L9.5
# 3                  1    2020/01/02   CONTACT RC INICELL, PF 4.0, E 3.5, L9.5
# 4                  1    2020/01/02     ELEMENT IMPL. RC INICELL® 3.0, L 12.5
#
#      GENERIC_NAME                      MANUFACTURER_D_NAME  \
# 0  DENTAL IMPLANT  IMPLANT DIRECT SYBRON MANUFACTURING LLC
# 1  DENTAL IMPLANT                       THOMMEN MEDICAL AG
# 2  DENTAL IMPLANT                       THOMMEN MEDICAL AG
# 3  DENTAL IMPLANT                       THOMMEN MEDICAL AG
# 4  DENTAL IMPLANT                       THOMMEN MEDICAL AG
#
#     MANUFACTURER_D_ADDRESS_1  ... COMBINATION_PRODUCT_FLAG          UDI-DI  \
# 0  3050 EAST HILLCREST DRIVE  ...                        N  10841307107415
# 1       NECKARSULMSTRASSE 28  ...                        N  07640156471441
# 2       NECKARSULMSTRASSE 28  ...                        N  07640156471304
# 3       NECKARSULMSTRASSE 28  ...                        N             NaN
# 4       NECKARSULMSTRASSE 28  ...                        N  07640156478556
#
#        UDI-PUBLIC year_x MDR_TEXT_KEY TEXT_TYPE_CODE PATIENT_SEQUENCE_NUMBER  \
# 0  10841307107415   2020    173287063              D                       1
# 1   7640156471441   2020    173274047              D                       1
# 2   7640156471304   2020    173274060              D                       1
# 3             NaN   2020    173273734              D                       1
# 4   7640156478556   2020    173274657              D                       1
#
#   DATE_REPORT                                           FOI_TEXT year_y
# 0         NaN  PER COMPLAINT (B)(4), AFTER CLINICAL PROCEDURE...   2020
# 1         NaN  LOSS OF OSSEOINTEGRATION, PRIMARY STABILITY WA...   2020
# 2         NaN  IMPLANT DIDN'T ACHIEVE OSSEOINTEGRATION, IMPLA...   2020
# 3         NaN  IMPLANT DIDN'T ACHIEVE OSSEOINTEGRATION, PRIMA...   2020
# 4         NaN  IMPLANT DIDN'T ACHIEVE OSSEOINTEGRATION, PRIMA...   2020
#
# [5 rows x 38 columns]
#
# === Missing Values in Merged Data ===
# MDR_REPORT_KEY                          0
# DEVICE_EVENT_KEY                  3634621
# IMPLANT_FLAG                      3634621
# DATE_REMOVED_FLAG                 3634621
# DEVICE_SEQUENCE_NO                      0
# DATE_RECEIVED                           0
# BRAND_NAME                           3763
# GENERIC_NAME                            0
# MANUFACTURER_D_NAME                  6863
# MANUFACTURER_D_ADDRESS_1            10620
# MANUFACTURER_D_ADDRESS_2          3226401
# MANUFACTURER_D_CITY                 10660
# MANUFACTURER_D_STATE_CODE         3007967
# MANUFACTURER_D_ZIP_CODE             38651
# MANUFACTURER_D_ZIP_CODE_EXT       2889441
# MANUFACTURER_D_COUNTRY_CODE         14031
# MANUFACTURER_D_POSTAL_CODE          38651
# DEVICE_OPERATOR                    227051
# EXPIRATION_DATE_OF_DEVICE         2745908
# MODEL_NUMBER                      2156848
# CATALOG_NUMBER                      56834
# LOT_NUMBER                         943355
# OTHER_ID_NUMBER                   3634621
# DEVICE_AVAILABILITY                     2
# DATE_RETURNED_TO_MANUFACTURER     1766334
# DEVICE_REPORT_PRODUCT_CODE              2
# DEVICE_AGE_TEXT                   2677915
# DEVICE_EVALUATED_BY_MANUFACTUR     124265
# COMBINATION_PRODUCT_FLAG               37
# UDI-DI                             996676
# UDI-PUBLIC                         996664
# year_x                                  0
# MDR_TEXT_KEY                            0
# TEXT_TYPE_CODE                          0
# PATIENT_SEQUENCE_NUMBER                 0
# DATE_REPORT                       3634621
# FOI_TEXT                                0
# year_y                                  0
# dtype: int64

# %%
# List of columns to drop (100% missing)
columns_to_drop = [
    "DEVICE_EVENT_KEY", 
    "IMPLANT_FLAG", 
    "DATE_REMOVED_FLAG", 
    "OTHER_ID_NUMBER", 
    "DATE_REPORT"
]

# Drop the columns from df_merged
df_cleaned = df_merged.drop(columns=columns_to_drop)

print("✅ 100% missing columns dropped successfully!")
# Out:
# ✅ 100% missing columns dropped successfully!

# %%
# Save merged DataFrame to a CSV file
output_csv_path = "merged_output_all.csv"  # Adjust file path/name as needed
df_merged.to_csv(output_csv_path, index=False)

print(f"✅ Merged data successfully saved to {output_csv_path}")
# Out:
# ✅ Merged data successfully saved to merged_output_all.csv
